# %% [markdown]
# # Deep Dive Analyst - Multi-Agent Research System
#
# **Instructions:**
# 1. Run Cell 1: Install dependencies
# 2. Run Cell 2: Configure API
# 3. Run Cell 3: Setup AI agents
# 4. Run Cell 4: Start interactive workflow

# %%
# !pip install -q google-generativeai
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Program Files\Python310\python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai

# Configure API
GOOGLE_API_KEY = "AIzaSyCJ2ZyGhcqgXFlPvKEczuibQDGZ9KXj41g"
genai.configure(api_key=GOOGLE_API_KEY)
print("✅ API configured")
# Out:
# ✅ API configured

# %%
# Agent A: Research Hunter (high creativity)
hunter_model = genai.GenerativeModel(
    "gemini-2.5-pro",
    generation_config={"temperature": 0.9, "max_output_tokens": 4096},
    system_instruction="You are a research analyst. Find facts, data, and recent developments."
)

# Agent B: Report Writer (high precision)
writer_model = genai.GenerativeModel(
    "gemini-2.5-flash",
    generation_config={"temperature": 0.2, "max_output_tokens": 4096},
    system_instruction="You are a technical writer. Create executive summaries from research data."
)

print("✅ Agents configured")
# Out:
# ✅ Agents configured

# %%
# Interactive workflow with human-in-the-loop

print("=" * 80)
print("DEEP DIVE ANALYST - Multi-Agent Research System")
print("=" * 80)

# Phase 1: User selects topic
topic = input("\n📌 What topic would you like to research? ")

# Phase 2: Agent A researches
print(f"\n🔍 Researching: {topic}...\n")
research_prompt = f"""Research this topic comprehensively: {topic}

Provide:
1. Current state and recent developments
2. Key statistics and data
3. Major players
4. Challenges and opportunities
5. Future outlook
"""

research = hunter_model.generate_content(research_prompt)
print("📊 RESEARCH FINDINGS:\n")
print(research.text)

# Phase 3: Human checkpoint
print("\n" + "=" * 80)
print("⏸️  HUMAN CHECKPOINT")
print("=" * 80)
feedback = input("\n👤 What should the final report focus on? ")

# Phase 4: Agent B writes report
print(f"\n✍️  Writing report focused on: {feedback}...\n")
report_prompt = f"""Write an executive report for decision-makers.

RESEARCH DATA:
{research.text}

USER FOCUS:
{feedback}

Create a 400-500 word report with:
- Executive Summary
- Key Findings
- Detailed Analysis (focused on user's direction)
- Recommendations

Prioritize the user's focus area."""

report = writer_model.generate_content(report_prompt)

print("=" * 80)
print("📄 FINAL REPORT")
print("=" * 80)
print(report.text)
print("\n✅ Complete! Run again to research a new topic.\n")
# Out:
# ================================================================================
# DEEP DIVE ANALYST - Multi-Agent Research System
# ================================================================================
#
# 🔍 Researching: ev vechiles...
#
# 📊 RESEARCH FINDINGS:
#
# Of course. As a research analyst, I have compiled a comprehensive report on the topic of Electric Vehicles (EVs).
#
# **Topic: Electric Vehicles (EVs)**
# **Date of Analysis:** May 2024
#
# ### Executive Summary
# The global electric vehicle market is at a critical inflection point. After a period of exponential, subsidy-fueled growth led by early adopters, the industry is now entering a more challenging phase of mainstream adoption. Key themes include intensifying price wars, the consolidation of charging standards, significant government policy influence, and a fierce technological race in battery innovation. While facing headwinds like infrastructure gaps and supply chain volatility, the long-term trajectory for EV adoption remains strongly positive, driven by environmental regulations, falling battery costs, and improving vehicle performance.
#
# ---
#
# ### 1. Current State and Recent Developments
#
# The EV market is transitioning from a niche segment to a significant portion of the automotive industry. This transition is marked by several key developments:
#
# *   **Slowing Growth Rate:** While still growing robustly, the *rate* of growth has slowed in late 2023 and early 2024 in key markets like Europe and North America. This is attributed to the exhaustion of the early-adopter pool, persistent high interest rates, and consumer anxiety over charging infrastructure and range.
# *   **Intensifying Price War:** Initiated by Tesla’s significant price cuts in 2023, a global price war has erupted. Ford, GM, and others have responded with their own price adjustments and incentive programs. This is squeezing profit margins but is seen as necessary to stimulate demand in the mainstream market.
# *   **Charging Standard Consolidation (North America):** In a landmark shift, nearly every major automaker (including Ford, GM, Rivian, Hyundai, and Volkswagen) has agreed to adopt Tesla's North American Charging Standard (NACS), now standardized as SAE J3400. This move is expected to unify and significantly improve the fragmented public charging experience in the US and Canada.
# *   **Policy as a Major Driver:** Government actions remain a primary force. The **U.S. Inflation Reduction Act (IRA)** provides tax credits but has stringent battery sourcing and manufacturing requirements, aiming to build a domestic supply chain. In Europe, the **"Fit for 55"** package maintains a 2035 target for phasing out new internal combustion engine (ICE) car sales, though discussions about e-fuels continue.
# *   **The Rise of Hybrids (PHEVs):** As a "bridge" technology, Plug-in Hybrid Electric Vehicles (PHEVs) are seeing a resurgence in popularity. Consumers are using them as a stepping stone to full electrification, appreciating the flexibility of having both an electric motor for daily commutes and a gasoline engine for long trips.
#
# ---
#
# ### 2. Key Statistics and Data
#
# *   **Global Sales:** Global sales of electric cars surpassed **14 million in 2023**, a 35% year-on-year increase. EVs accounted for **18% of all new cars sold** globally in 2023, up from 14% in 2022. (Source: International Energy Agency, IEA)
# *   **Market Share by Region (2023):**
#     *   **China:** The largest market, accounting for nearly **60%** of global EV sales. Over one-third of new cars sold in China are now electric.
#     *   **Europe:** The second-largest market, with a market share of around **25%** of new car sales in key countries.
#     *   **United States:** The third-largest market, where EV sales surpassed 1 million units for the first time in 2023, reaching a market share of about **9%**.
# *   **Battery Costs:** The average price of a lithium-ion battery pack fell to a record low of **$139/kWh** at the end of 2023. This is an 89% decrease since 2008. However, volatility in raw material prices (lithium, cobalt, nickel) can cause short-term price fluctuations. Cost parity with ICE vehicles is expected when prices approach **$100/kWh**. (Source: BloombergNEF)
# *   **Charging Infrastructure:** There are over **3 million public charging points** worldwide. However, the rollout of DC fast chargers, which are critical for long-distance travel, still lags behind the growth in EV sales, and charger reliability remains a significant issue.
#
# ---
#
# ### 3. Major Players
#
# The competitive landscape is comprised of EV-native companies and legacy automakers undergoing massive transformations.
#
# *   **Market Leaders:**
#     *   **Tesla (USA):** The global pioneer and technology leader. While its market share is being challenged, it remains the benchmark for software, efficiency, and charging infrastructure (Supercharger Network).
#     *   **BYD (China):** Surpassed Tesla in quarterly BEV sales in Q4 2023. A vertically integrated behemoth that manufactures its own batteries (Blade Battery), semiconductors, and vehicles. It dominates the Chinese market and is rapidly expanding globally with a range of affordable to premium models.
# *   **Legacy Automakers in Transition:**
#     *   **Volkswagen Group (Germany):** One of the most aggressive legacy automakers, investing heavily in its "ID" family of EVs across its brands (VW, Audi, Porsche).
#     *   **Hyundai Motor Group (South Korea):** Includes Hyundai, Kia, and Genesis. Their E-GMP platform has received critical acclaim for its 800-volt architecture, enabling ultra-fast charging.
#     *   **General Motors (USA):** Betting its future on the Ultium battery platform, with models like the Hummer EV, Cadillac Lyriq, and the mass-market Chevrolet Equinox EV.
#     *   **Ford (USA):** Gained early traction with the Mustang Mach-E and F-150 Lightning but is now restructuring its EV division ("Model e") to achieve profitability.
# *   **Emerging Players & EV Startups:**
#     *   **Rivian (USA):** Carved a niche in the premium "adventure vehicle" market with its R1T truck and R1S SUV.
#     *   **Lucid Motors (USA):** Focuses on the ultra-luxury segment with industry-leading range and performance but faces significant production and financial hurdles.
#     *   **NIO, XPeng, Li Auto (China):** Major Chinese players known for innovation in areas like battery-swapping (NIO) and advanced driver-assistance systems (XPeng).
#
# ---
#
# ### 4. Challenges and Opportunities
#
# **Challenges:**
#
# *   **Charging Infrastructure:** The biggest barrier to mass adoption. Issues include the sheer number of chargers needed, reliability and uptime, complex payment systems, and slow charging speeds in many locations.
# *   **Grid Capacity:** Mass EV adoption will place significant strain on national electricity grids, requiring massive investment in generation, transmission, and smart grid technology to manage peak demand.
# *   **Supply Chain & Geopolitics:** The EV supply chain is heavily dependent on a few countries for critical raw materials (lithium, cobalt, nickel) and battery processing, creating geopolitical and ethical sourcing risks.
# *   **Upfront Cost and Profitability:** EVs still have a higher sticker price than comparable ICE vehicles, and most automakers outside of Tesla and BYD are still losing money on each EV they sell.
# *   **Battery Degradation & Repair:** Long-term battery health, replacement costs, and the complexity of repairing damaged battery packs are growing consumer concerns.
#
# **Opportunities:**
#
# *   **Total Cost of Ownership (TCO):** Lower "fueling" (electricity) and maintenance costs can make EVs cheaper to own over their lifespan, a key selling point for mainstream consumers and fleet operators.
# *   **Vehicle-to-Grid (V2G) Technology:** This allows EVs to act as mobile batteries, storing energy when demand is low and selling it back to the grid during peak hours. This can stabilize the grid and create a new revenue stream for EV owners.
# *   **Software and Services:** EVs are essentially computers on wheels. This creates opportunities for recurring revenue through over-the-air (OTA) software updates, feature subscriptions (e.g., enhanced autonomous driving), and in-car infotainment.
# *   **Environmental Impact:** EVs offer zero tailpipe emissions, leading to improved urban air quality. The overall lifecycle emissions are continually improving as electricity grids become greener and battery recycling processes mature.
#
# ---
#
# ### 5. Future Outlook
#
# The next 5-10 years will be transformative for the EV industry.
#
# *   **Battery Technology Breakthroughs:** The race is on for the next generation of batteries.
#     *   **Solid-State Batteries:** Considered the "holy grail," promising higher energy density (longer range), faster charging, and improved safety. Companies like Toyota, QuantumScape, and Solid Power are leading the research, with commercially viable products expected around the end of the decade.
#     *   **Sodium-Ion Batteries:** A cheaper
#
# ================================================================================
# ⏸️  HUMAN CHECKPOINT
# ================================================================================
#
# ✍️  Writing report focused on: focus on its enviromental and economical impact...
#
# ================================================================================
# 📄 FINAL REPORT
# ================================================================================
# ## Executive Report: Electric Vehicles – Navigating Environmental Imperatives and Economic Realities
#
# **Date:** May 2024
#
# ### Executive Summary
#
# The Electric Vehicle (EV) market is undergoing a significant transformation, moving from early adoption to mainstream integration. This shift is characterized by a complex interplay of environmental drivers and economic pressures. While EVs offer substantial environmental benefits through reduced emissions and improved air quality, the industry faces economic headwinds including intensifying price wars, high upfront costs, and supply chain vulnerabilities. Government policies globally are pivotal in shaping both the environmental trajectory and economic viability of the sector. Long-term growth remains robust, driven by falling battery costs and a growing focus on sustainable transportation, but strategic decisions are critical to navigate current challenges and unlock future opportunities.
#
# ### Key Findings
#
# *   **Environmental Imperative:** EVs are crucial for achieving climate goals, offering zero tailpipe emissions and improving urban air quality. Lifecycle emissions are also improving with greener energy grids.
# *   **Economic Headwinds:** A global price war is squeezing profit margins, and EVs still carry a higher upfront cost than comparable Internal Combustion Engine (ICE) vehicles, impacting mainstream adoption.
# *   **Cost Reduction & TCO:** Battery costs have fallen dramatically (89% since 2008 to $139/kWh), making EVs more economically viable over their lifespan due to lower "fueling" and maintenance costs.
# *   **Policy Influence:** Government incentives (e.g., U.S. IRA) and emission targets (e.g., EU "Fit for 55") are primary drivers, shaping market dynamics and supply chain development.
# *   **Infrastructure & Supply Chain Gaps:** Inadequate charging infrastructure and geopolitical risks associated with critical raw material sourcing remain significant economic and operational challenges.
#
# ### Detailed Analysis: Environmental and Economic Impact
#
# The transition to EVs presents a dual imperative: mitigating environmental impact while fostering economic sustainability.
#
# **Environmental Impact:** EVs are a cornerstone of global decarbonization efforts. Their primary environmental benefit is the elimination of tailpipe emissions, directly contributing to cleaner urban air and reducing greenhouse gas output. As electricity grids increasingly integrate renewable energy sources, the overall lifecycle emissions of EVs continue to improve, making them a progressively greener alternative to ICE vehicles. Policies like Europe's "Fit for 55" package, targeting a 2035 phase-out of new ICE sales, underscore the environmental urgency driving this transition. However, the environmental benefits are contingent on grid decarbonization; reliance on fossil fuel-generated electricity diminishes the net positive impact.
#
# **Economic Impact:** Economically, the EV market is a landscape of both immense opportunity and significant challenge. The dramatic reduction in battery costs, now at $139/kWh, is a pivotal factor, making EVs more competitive and improving their Total Cost of Ownership (TCO) through lower energy and maintenance expenses. This TCO advantage is a key selling point for mainstream consumers and fleet operators. However, the industry is grappling with an intensifying price war, initiated by market leaders, which is severely compressing profit margins for many automakers. The higher upfront purchase price of EVs remains a barrier for many consumers, despite incentives. Furthermore, the supply chain for critical raw materials (lithium, cobalt, nickel) is concentrated and susceptible to geopolitical risks and price volatility, posing a significant economic and strategic challenge. Investment in charging infrastructure and grid capacity also represents a massive economic undertaking, essential for mass adoption but requiring substantial capital. Opportunities exist in Vehicle-to-Grid (V2G) technology, which can stabilize grids and create new revenue streams, and in software-driven services, offering recurring revenue potential.
#
# ### Recommendations
#
# 1.  **Strategic Infrastructure Investment:** Prioritize and incentivize the rapid expansion of reliable, fast-charging infrastructure, including public and private solutions, to alleviate consumer anxiety and unlock mainstream adoption.
# 2.  **Supply Chain Diversification & Localization:** Support initiatives (e.g., through tax credits and grants) aimed at diversifying and localizing the EV battery and raw material supply chain to mitigate geopolitical risks and ensure long-term economic stability.
# 3.  **Policy & Incentive Optimization:** Implement targeted policies that balance environmental goals with economic realities, focusing on incentives that reduce upfront costs for consumers while fostering innovation and profitability for manufacturers.
# 4.  **Grid Modernization & V2G Integration:** Invest in smart grid technologies and promote Vehicle-to-Grid (V2G) capabilities to manage increased electricity demand, enhance grid stability, and create new economic value from EV fleets.
#
# ✅ Complete! Run again to research a new topic.
