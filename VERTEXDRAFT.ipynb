# %% [markdown]
# # Deep Dive Analyst - Multi-Agent Research System
#
# **Quick Start: Run All Cells (Cells 1-4) for Complete Demo**
#
# This notebook demonstrates a multi-agent AI system with human-in-the-loop control:
# - **Agent A (Hunter)**: Conducts comprehensive research
# - **Agent B (Writer)**: Generates focused executive reports
# - **Human Control**: Directs analysis focus at critical checkpoint
#
# **Note**: Demo mode uses hardcoded inputs for automatic execution (safe for Kaggle/background runs)

# %%
# !pip install -q google-generativeai
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Program Files\Python310\python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai

# Configure API
GOOGLE_API_KEY = "AIzaSyCJ2ZyGhcqgXFlPvKEczuibQDGZ9KXj41g"
genai.configure(api_key=GOOGLE_API_KEY)
print("✅ API configured")
# Out:
# ✅ API configured

# %%
# Agent A: Research Hunter (high creativity)
hunter_model = genai.GenerativeModel(
    "gemini-2.5-pro",
    generation_config={"temperature": 0.9, "max_output_tokens": 4096},
    system_instruction="You are a research analyst. Find facts, data, and recent developments."
)

# Agent B: Report Writer (high precision)
writer_model = genai.GenerativeModel(
    "gemini-2.5-flash",
    generation_config={"temperature": 0.2, "max_output_tokens": 4096},
    system_instruction="You are a technical writer. Create executive summaries from research data."
)

print("✅ Agents configured")
# Out:
# ✅ Agents configured

# %%
# Interactive workflow with human-in-the-loop

print("=" * 80)
print("DEEP DIVE ANALYST - Multi-Agent Research System")
print("=" * 80)

# Phase 1: User selects topic
topic = input("\n📌 What topic would you like to research? ")

# Phase 2: Agent A researches
print(f"\n🔍 Researching: {topic}...\n")
research_prompt = f"""Research this topic comprehensively: {topic}

Provide:
1. Current state and recent developments
2. Key statistics and data
3. Major players
4. Challenges and opportunities
5. Future outlook
"""

research = hunter_model.generate_content(research_prompt)
print("📊 RESEARCH FINDINGS:\n")
print(research.text)

# Phase 3: Human checkpoint
print("\n" + "=" * 80)
print("⏸️  HUMAN CHECKPOINT")
print("=" * 80)
feedback = input("\n👤 What should the final report focus on? ")

# Phase 4: Agent B writes report
print(f"\n✍️  Writing report focused on: {feedback}...\n")
report_prompt = f"""Write an executive report for decision-makers.

RESEARCH DATA:
{research.text}

USER FOCUS:
{feedback}

Create a 400-500 word report with:
- Executive Summary
- Key Findings
- Detailed Analysis (focused on user's direction)
- Recommendations

Prioritize the user's focus area."""

report = writer_model.generate_content(report_prompt)

print("=" * 80)
print("📄 FINAL REPORT")
print("=" * 80)
print(report.text)
print("\n✅ Complete! Run again to research a new topic.\n")
# Out:
# ================================================================================
# DEEP DIVE ANALYST - Multi-Agent Research System
# ================================================================================
#
# 🔍 Researching: AI RESEARCH SCIENTIST...
#
# 📊 RESEARCH FINDINGS:
#
# Of course. Here is a comprehensive research report on the role of the AI Research Scientist.
#
# ### **AI Research Scientist: A Comprehensive Analysis**
#
# **Executive Summary:** The role of the AI Research Scientist is at the epicenter of the current technological revolution. These individuals are responsible for creating the fundamental breakthroughs that power the next generation of artificial intelligence. The field has rapidly shifted from niche academic pursuit to the primary driver of innovation in the world's largest technology companies. Driven by the success of large-scale models, particularly in generative AI, the demand, compensation, and influence of AI Research Scientists have reached unprecedented levels. However, the field faces significant challenges related to computational costs, ethical considerations, and a looming talent war.
#
# ---
#
# ### **1. Current State and Recent Developments**
#
# The current state of AI research is characterized by rapid, large-scale advancements, moving from incremental improvements to major paradigm shifts.
#
# *   **The Dominance of Foundation Models:** The primary focus of cutting-edge research has shifted to "foundation models"—massive, self-supervised models trained on vast, web-scale datasets (e.g., GPT-4, Llama 3, Gemini, Claude 3). These models serve as a base that can be fine-tuned for a wide array of downstream tasks, from coding and writing to image analysis and scientific modeling.
# *   **The Generative AI Explosion:** The most visible development is the explosion in generative capabilities.
#     *   **Language:** Large Language Models (LLMs) now exhibit sophisticated reasoning, translation, and creative writing abilities, increasingly functioning as "reasoning engines."
#     *   **Vision & Video:** Diffusion models and generative adversarial networks (GANs) have led to text-to-image models (e.g., DALL-E 3, Midjourney) and nascent text-to-video models (e.g., OpenAI's Sora, Google's Lumiere) that are approaching photorealism.
# *   **Multi-modality:** Research is aggressively pushing towards models that can seamlessly process and generate information across different modalities—text, images, audio, and video. Google's Gemini and OpenAI's GPT-4V are prime examples, capable of analyzing images and answering complex questions about them.
# *   **AI for Science:** A major development is the application of AI to solve fundamental scientific problems. DeepMind's **AlphaFold** solved the 50-year-old grand challenge of protein structure prediction, revolutionizing drug discovery. Similarly, projects like Google's GNoME are using AI to discover new materials.
# *   **Open-Source vs. Closed-Source Debate:** The research community is split. Companies like OpenAI and Anthropic keep their most powerful models proprietary ("closed"), while others like Meta (with its Llama series) and Mistral AI are championing an open-source approach, accelerating innovation and accessibility globally.
# *   **Focus on Efficiency:** As models grow, a parallel research track is focused on making them more efficient through techniques like **quantization** (reducing model precision), **LoRA** (Low-Rank Adaptation), and developing smaller, highly-performant models (e.g., Microsoft's Phi-3).
#
# ---
#
# ### **2. Key Statistics and Data**
#
# *   **Compensation:** The demand for top-tier talent has driven salaries to extraordinary levels.
#     *   **Entry-Level (PhD Graduate):** Total compensation typically ranges from **$250,000 to $450,000 USD** at major tech firms.
#     *   **Senior/Staff Scientist:** Compensation can easily range from **$500,000 to over $1,000,000 USD**, heavily weighted towards stock options.
#     *   **Top-Tier Researchers:** Leading figures in the field can command multi-million dollar packages, rivaling executive-level compensation. (Source: Levels.fyi, industry reports).
# *   **Job Market Growth:** The Bureau of Labor Statistics projects that employment for "Computer and Information Research Scientists" will grow by **23%** from 2022 to 2032, much faster than the average for all occupations. The AI-specific subset of this role is growing even faster.
# *   **Publication Volume:** The number of papers submitted to top AI conferences like NeurIPS, ICML, and ICLR has exploded. For example, NeurIPS received over **12,300 submissions in 2023**, up from just over 2,000 five years prior, indicating a massive increase in research activity.
# *   **Model Scale & Cost:**
#     *   **Parameters:** Leading models have surpassed hundreds of billions of parameters (e.g., GPT-3 had 175B). Rumored parameter counts for newer models are in the trillions (though often using Mixture-of-Experts architectures).
#     *   **Training Costs:** The cost to train a single state-of-the-art foundation model is estimated to be in the **tens to hundreds of millions of dollars**, limiting this research to a handful of well-funded organizations.
#
# ---
#
# ### **3. Major Players**
#
# The landscape is dominated by a few key types of organizations, creating a highly concentrated ecosystem.
#
# *   **Industrial Research Labs:** These are the most dominant forces, attracting the best talent with immense computational resources and funding.
#     *   **Google DeepMind:** A powerhouse known for landmark achievements like AlphaGo, AlphaFold, and the Gemini models.
#     *   **Meta AI (FAIR):** A leading research lab responsible for foundational work in computer vision, the PyTorch framework, and the influential open-source Llama models.
#     *   **OpenAI:** The company that brought generative AI into the mainstream with GPT-3, DALL-E, and ChatGPT. Their stated mission is to achieve Artificial General Intelligence (AGI).
#     *   **Microsoft Research:** A long-standing institution now deeply integrated with OpenAI, also producing its own influential research on model efficiency and smaller models.
# *   **High-Growth Startups:** A new wave of well-funded startups is challenging the incumbents.
#     *   **Anthropic:** Founded by ex-OpenAI researchers with a primary focus on AI safety and alignment, producing the Claude family of models.
#     *   **Mistral AI:** A Paris-based startup that has quickly gained prominence by releasing powerful open-source models.
#     *   **Cohere:** Focuses on building enterprise-grade LLMs and retrieval-augmented generation (RAG) systems.
# *   **Academia:** Universities remain crucial for fundamental, curiosity-driven research and for training the next generation of scientists. However, they struggle to compete with industry on salary and compute resources, leading to a significant "brain drain."
#     *   **Key Institutions:** Stanford University (HAI), Carnegie Mellon University (SCS), MIT (CSAIL), UC Berkeley (BAIR), and the University of Toronto (Vector Institute).
# *   **Hardware Providers (The Enablers):**
#     *   **NVIDIA:** Holds a near-monopoly on the high-end GPUs (e.g., H100, B200) required for training large models, making it a critical player in the research ecosystem.
#
# ---
#
# ### **4. Challenges and Opportunities**
#
# **Challenges:**
#
# *   **The Compute Wall:** The cost of computation is the single biggest barrier to entry and progress. Only a few companies can afford to train models at the cutting edge, leading to a centralization of power.
# *   **AI Safety and Alignment:** Ensuring that increasingly powerful AI systems are safe, controllable, and aligned with human values is a paramount and unsolved research problem. Issues include "hallucinations," bias, and potential for misuse.
# *   **Data Scarcity:** While trained on "the internet," researchers are finding that the supply of high-quality public text and image data is finite. Future progress may depend on synthetic data generation or access to proprietary datasets.
# *   **Reproducibility Crisis:** The massive scale and cost of experiments make it difficult for others to reproduce and verify results, a cornerstone of the scientific method.
# *   **Ethical Dilemmas:** Researchers are on the front lines of ethical issues, including algorithmic bias, job displacement, privacy violations, and the potential for autonomous weapons or mass disinformation campaigns.
#
# **Opportunities:**
#
# *   **Solving Grand Scientific Challenges:** AI offers the potential to accelerate discovery in nearly every scientific field, from medicine and materials science to climate change modeling and astrophysics.
# *   **Augmenting Human Intelligence:** The opportunity is not just to automate tasks but to create powerful tools that act as collaborators for coders, designers, scientists, and educators, dramatically increasing human productivity and creativity.
# *   **Development of AI Agents:** The next frontier is moving from passive models to active "agents" that can perform multi-step tasks, use tools, and interact with digital environments to achieve complex goals.
# *   **Personalization at Scale:** AI research
#
# ================================================================================
# ⏸️  HUMAN CHECKPOINT
# ================================================================================
#
# ✍️  Writing report focused on: ITS ROLE...
#
# ================================================================================
# 📄 FINAL REPORT
# ================================================================================
# ## Executive Report: The Pivotal Role of the AI Research Scientist
#
# ### Executive Summary
#
# The AI Research Scientist stands as the primary architect of the current technological revolution, driving fundamental breakthroughs in artificial intelligence. This role is critical for developing the next generation of AI, particularly in foundation models and generative AI, which are reshaping industries globally. While demand and compensation for these specialists are unprecedented, the field faces significant challenges related to computational costs, ethical considerations, and an intense talent war. Strategic investment in this role is paramount for future innovation and competitive advantage.
#
# ### Key Findings
#
# *   **Innovation Drivers:** AI Research Scientists are responsible for developing "foundation models" (e.g., LLMs, vision models) that serve as the base for a vast array of AI applications, moving the field from incremental improvements to paradigm shifts.
# *   **Generative AI Explosion:** Their work has led to the rapid advancement of generative AI, enabling sophisticated reasoning, creative content generation, and multi-modal capabilities across text, image, and video.
# *   **Extraordinary Demand & Compensation:** The demand for top-tier AI Research Scientists is exceptionally high, with compensation packages ranging from $250,000 for entry-level PhDs to over $1,000,000 for senior roles, reflecting their critical value.
# *   **Concentrated Power:** Research and development are heavily concentrated in a few industrial labs (Google DeepMind, Meta AI, OpenAI, Microsoft Research) due to the immense computational resources required.
# *   **Critical Challenges:** The role is increasingly constrained by the "compute wall," AI safety and alignment issues, data scarcity, and complex ethical dilemmas.
#
# ### Detailed Analysis: The Pivotal Role of the AI Research Scientist
#
# The AI Research Scientist is not merely an implementer but a visionary and architect, operating at the cutting edge of theoretical and applied AI. Their role is fundamentally about **discovery and innovation**, pushing the boundaries of what artificial intelligence can achieve. They are the individuals who conceive, design, and train the massive, complex models that underpin modern AI systems.
#
# Specifically, their responsibilities include:
#
# 1.  **Developing Foundation Models:** They are the primary drivers behind the creation of large-scale, self-supervised models like GPT-4 or Llama 3. This involves deep expertise in machine learning theory, neural network architectures, and extensive experimentation with vast datasets to create models capable of diverse tasks.
# 2.  **Pioneering Generative AI:** AI Research Scientists are at the forefront of developing generative capabilities, enabling AI to create human-like text, photorealistic images, and increasingly, video. This requires innovative approaches to model design and training methodologies.
# 3.  **Applying AI to Grand Challenges:** A significant aspect of their role involves leveraging AI to solve fundamental scientific problems, as exemplified by AlphaFold's impact on protein folding or AI's use in discovering new materials. They translate complex scientific questions into solvable AI problems.
# 4.  **Optimizing Efficiency and Scale:** As models grow, these scientists are crucial in developing techniques (e.g., quantization, LoRA) to make AI more efficient, accessible, and sustainable, balancing performance with computational cost.
# 5.  **Addressing Safety and Ethics:** A critical, and increasingly prominent, part of their role involves researching and implementing solutions for AI safety, alignment, and ethical considerations. They are on the front lines of mitigating biases, preventing misuse, and ensuring AI systems are robust and trustworthy.
#
# In essence, AI Research Scientists are the intellectual engine of the AI revolution, responsible for both the theoretical breakthroughs and the practical advancements that define the field's trajectory.
#
# ### Recommendations
#
# 1.  **Invest in Top Talent:** Prioritize attracting and retaining elite AI Research Scientists through competitive compensation, unparalleled computational resources, and a culture that fosters groundbreaking research.
# 2.  **Strategic Compute Allocation:** Ensure dedicated and substantial access to high-performance computing infrastructure, recognizing it as the primary enabler of cutting-edge AI research.
# 3.  **Prioritize AI Safety & Ethics Research:** Allocate significant resources to research focused on AI safety, alignment, and ethical development to mitigate risks associated with increasingly powerful AI systems.
# 4.  **Foster Collaboration:** Encourage partnerships with leading academic institutions to tap into fundamental research and cultivate the next generation of AI talent.
#
# ✅ Complete! Run again to research a new topic.
